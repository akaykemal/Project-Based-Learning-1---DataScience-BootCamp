# %%
# this project was done in colab

# %%
#!pip install pycaret

# %% [markdown]
# # Try Regression with Pycaret

# %%
import pandas as pd

# %%
from pycaret.regression import *

# %%
df=pd.read_csv("advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
setup(data=df,target="Sales")
# Out:
#                                Description             Value
# 0                               session_id              8720
# 1                                   Target             Sales
# 2                            Original Data          (200, 4)
# 3                           Missing Values             False
# 4                         Numeric Features                 3
# 5                     Categorical Features                 0
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set          (139, 3)
# 10                    Transformed Test Set           (61, 3)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
best_model=compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  0.4441   0.4712  0.6082  0.9839
# gbr           Gradient Boosting Regressor  0.5512   0.6393  0.7502  0.9774
# rf                Random Forest Regressor  0.6379   0.7894  0.8373  0.9728
# ada                    AdaBoost Regressor  0.9056   1.4221  1.1548  0.9482
# dt                Decision Tree Regressor  0.9281   1.4946  1.1804  0.9420
# lightgbm  Light Gradient Boosting Machine  0.9005   1.7123  1.2236  0.9399
# lasso                    Lasso Regression  1.2136   2.8947  1.6261  0.8997
# en                            Elastic Net  1.2140   2.9024  1.6271  0.8995
# ridge                    Ridge Regression  1.2147   2.9116  1.6279  0.8993
# lar                Least Angle Regression  1.2147   2.9117  1.6279  0.8993
# lr                      Linear Regression  1.2147   2.9117  1.6279  0.8993
# ...
